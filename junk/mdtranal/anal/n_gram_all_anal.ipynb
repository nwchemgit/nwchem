# %%
import pickle
# %matplotlib inline
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import os
import glob

# %%
os.getcwd()
os.chdir("../data")
os.getcwd()

df_lst = []
for file in glob.glob("ee*.json.df"):
    print("Processing :" + file)

    with open(file, 'rb') as handle:
        ldf = pd.read_pickle(handle)
        df_lst.append(ldf)
df = pd.concat(df_lst)
# Out:
# Processing :ee-test-for-ml-lammps-128+128.3755465.0.json.df
# Processing :ee-test-for-ml-lammps-128+128.3755465.10.json.df
# Processing :ee-test-for-ml-lammps-128+128.3755465.100.json.df
# Processing :ee-test-for-ml-lammps-128+128.3755465.101.json.df
# Processing :ee-test-for-ml-lammps-128+128.3755465.102.json.df
# Processing :ee-test-for-ml-lammps-128+128.3755465.103.json.df
# Processing :ee-test-for-ml-lammps-128+128.3755465.104.json.df
# Processing :ee-test-for-ml-lammps-128+128.3755465.105.json.df
# Processing :ee-test-for-ml-lammps-128+128.3755465.106.json.df
# Processing :ee-test-for-ml-lammps-128+128.3755465.107.json.df
# Processing :ee-test-for-ml-lammps-128+128.3755465.108.json.df
# Processing :ee-test-for-ml-lammps-128+128.3755465.109.json.df
# Processing :ee-test-for-ml-lammps-128+128.3755465.110.json.df
# Processing :ee-test-for-ml-lammps-128+128.3755465.111.json.df
# Processing :ee-test-for-ml-lammps-128+128.3755465.112.json.df
# Processing :ee-test-for-ml-lammps-128+128.3755465.113.json.df
# Processing :ee-test-for-ml-lammps-128+128.3755465.114.json.df
# Processing :ee-test-for-ml-lammps-128+128.3755465.115.json.df
# Processing :ee-test-for-ml-lammps-128+128.3755465.116.json.df
# Processing :ee-test-for-ml-lammps-128+32.3755463.110.json.df
# Processing :ee-test-for-ml-lammps-128+32.3755463.112.json.df

# %%
df
# Out:
#                                                        kl  time_by_lasttime  \
# 0                              .TAUapplication:MPI_Init()          0.000011
# 1       intmain(int,char**):voidLAMMPS_NS::LAMMPS::LAM...          0.019102
# 2       intmain(int,char**):voidLAMMPS_NS::LAMMPS::LAM...          0.019106
# 3       intmain(int,char**):voidLAMMPS_NS::LAMMPS::LAM...          0.019111
# 4       intmain(int,char**):voidLAMMPS_NS::LAMMPS::LAM...          0.019115
# 5       .TAUapplication:intmain(int,char**):voidLAMMPS...          0.019099
# 6       intmain(int,char**):voidLAMMPS_NS::LAMMPS::LAM...          0.019133
# 7       intmain(int,char**):voidLAMMPS_NS::LAMMPS::LAM...          0.019133
# 8       .TAUapplication:intmain(int,char**):voidLAMMPS...          0.019133
# 9       .TAUapplication:intmain(int,char**):intLAMMPS_...          0.019137
# 10      .TAUapplication:intmain(int,char**):MPI_Type_s...          0.020131
# 11      .TAUapplication:intmain(int,char**):MPI_Type_s...          0.020132
# 12      .TAUapplication:intmain(int,char**):voidLAMMPS...          0.020138
# 13      intmain(int,char**):voidLAMMPS_NS::LAMMPS::LAM...          0.020143
# 14      intmain(int,char**):voidLAMMPS_NS::LAMMPS::LAM...          0.020143
# 15      voidLAMMPS_NS::LAMMPS::LAMMPS(int,char**,MPI_C...          0.020147
# 16      intmain(int,char**):voidLAMMPS_NS::LAMMPS::LAM...          0.020147
# 17      .TAUapplication:intmain(int,char**):voidLAMMPS...          0.020143
# 18      voidLAMMPS_NS::LAMMPS::LAMMPS(int,char**,MPI_C...          0.020164
# 19      voidLAMMPS_NS::LAMMPS::LAMMPS(int,char**,MPI_C...          0.020164
# 20      intmain(int,char**):voidLAMMPS_NS::LAMMPS::LAM...          0.020164
# 21      voidLAMMPS_NS::LAMMPS::create():voidLAMMPS_NS:...          0.020172
# 22      voidLAMMPS_NS::LAMMPS::create():voidLAMMPS_NS:...          0.020173
# 23      voidLAMMPS_NS::CommBrick::CommBrick(LAMMPS_NS:...          0.020178
# 24      voidLAMMPS_NS::CommBrick::CommBrick(LAMMPS_NS:...          0.020178
# 25      voidLAMMPS_NS::CommBrick::CommBrick(LAMMPS_NS:...          0.020179
# 26      voidLAMMPS_NS::CommBrick::CommBrick(LAMMPS_NS:...          0.020180
# 27      voidLAMMPS_NS::CommBrick::CommBrick(LAMMPS_NS:...          0.020180
# 28      voidLAMMPS_NS::CommBrick::CommBrick(LAMMPS_NS:...          0.020180
# 29      voidLAMMPS_NS::CommBrick::CommBrick(LAMMPS_NS:...          0.020180
# ...                                                   ...               ...
# 173991  voidLAMMPS_NS::LAMMPS::destroy():voidLAMMPS_NS...          0.932250
# 173992  voidLAMMPS_NS::LAMMPS::~LAMMPS():voidLAMMPS_NS...          0.932250
# 173993  intmain(int,char**):voidLAMMPS_NS::LAMMPS::~LA...          0.932215
# 173994  .TAUapplication:intmain(int,char**):voidLAMMPS...          0.931954
# 173995  .TAUapplication:intmain(int,char**):voidLAMMPS...          0.932254
# 173996  intmain(int,char**):voidLAMMPS_NS::LAMMPS::~LA...          0.932255
# 173997  intmain(int,char**):voidLAMMPS_NS::LAMMPS::~LA...          0.932255
# 173998  intmain(int,char**):voidLAMMPS_NS::LAMMPS::~LA...          0.932257
# 173999  intmain(int,char**):voidLAMMPS_NS::LAMMPS::~LA...          0.932257
# 174000  intmain(int,char**):voidLAMMPS_NS::LAMMPS::~LA...          0.932257
# 174001  voidLAMMPS_NS::LAMMPS::~LAMMPS():voidLAMMPS_NS...          0.932259
# 174002  voidLAMMPS_NS::LAMMPS::~LAMMPS():voidLAMMPS_NS...          0.932259
# 174003  voidLAMMPS_NS::LAMMPS::~LAMMPS():voidLAMMPS_NS...          0.932259
# 174004  voidLAMMPS_NS::LAMMPS::~LAMMPS():voidLAMMPS_NS...          0.932259
# 174005  voidLAMMPS_NS::LAMMPS::~LAMMPS():voidLAMMPS_NS...          0.932259
# 174006  voidLAMMPS_NS::LAMMPS::~LAMMPS():voidLAMMPS_NS...          0.932260
# 174007  voidLAMMPS_NS::LAMMPS::~LAMMPS():voidLAMMPS_NS...          0.932260
# 174008  voidLAMMPS_NS::LAMMPS::~LAMMPS():voidLAMMPS_NS...          0.932260
# 174009  voidLAMMPS_NS::LAMMPS::~LAMMPS():voidLAMMPS_NS...          0.932260
# 174010  voidLAMMPS_NS::LAMMPS::~LAMMPS():voidLAMMPS_NS...          0.932260
# 174011  intmain(int,char**):voidLAMMPS_NS::LAMMPS::~LA...          0.932259
# 174012  .TAUapplication:intmain(int,char**):voidLAMMPS...          0.932255
# 174013  intmain(int,char**):voidLAMMPS_NS::LAMMPS::~LA...          0.932705
# 174014  intmain(int,char**):voidLAMMPS_NS::LAMMPS::~LA...          0.932707
# 174015  intmain(int,char**):voidLAMMPS_NS::LAMMPS::~LA...          0.932707
# 174016  .TAUapplication:intmain(int,char**):voidLAMMPS...          0.932264
# 174017   .TAUapplication:voidLAMMPS_NS::LAMMPS::~LAMMPS()          0.931951
# 174018                      .TAUapplication:MPI_Barrier()          0.932707
# 174019                     .TAUapplication:MPI_Finalize()          0.933563
# 174020                                intmain(int,char**)          0.000007
#
#         time_diff node_id thread_id
# 0         55893.0       0         0
# 1             3.0       0         0
# 2             1.0       0         0
# 3             1.0       0         0
# 4             1.0       0         0
# 5           181.0       0         0
# 6             1.0       0         0
# 7             1.0       0         0
# 8             4.0       0         0
# 9             1.0       0         0
# 10            4.0       0         0
# 11            1.0       0         0
# 12            1.0       0         0
# 13            1.0       0         0
# 14            2.0       0         0
# 15            1.0       0         0
# 16            2.0       0         0
# 17           69.0       0         0
# 18            0.0       0         0
# 19            1.0       0         0
# 20            3.0       0         0
# 21            5.0       0         0
# 22            4.0       0         0
# 23            1.0       0         0
# 24            9.0       0         0
# 25            1.0       0         0
# 26            0.0       0         0
# 27            0.0       0         0
# 28            0.0       0         0
# 29            1.0       0         0
# ...           ...     ...       ...
# 173991        0.0     112         0
# 173992        0.0     112         0
# 173993      200.0     112         0
# 173994     1710.0     112         0
# 173995        0.0     112         0
# 173996        0.0     112         0
# 173997        0.0     112         0
# 173998        0.0     112         0
# 173999        0.0     112         0
# 174000        0.0     112         0
# 174001        0.0     112         0
# 174002        0.0     112         0
# 174003        0.0     112         0
# 174004        0.0     112         0
# 174005        0.0     112         0
# 174006        0.0     112         0
# 174007        0.0     112         0
# 174008        0.0     112         0
# 174009        0.0     112         0
# 174010        0.0     112         0
# 174011       10.0     112         0
# 174012       30.0     112         0
# 174013       10.0     112         0
# 174014        0.0     112         0
# 174015        0.0     112         0
# 174016     2560.0     112         0
# 174017     4370.0     112         0
# 174018     4930.0     112         0
# 174019   383930.0     112         0
# 174020  5778861.0     112         0
#
# [3623214 rows x 5 columns]

# %%
df = df.sort(['time_by_lasttime'], ascending=[True])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-680d34bee415> in <module>()
# ----> 1 df = df.sort(['time_by_lasttime'], ascending=[True])
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'sort'

# %%
import pandas as pd
sf = df.kl.value_counts()
freq = pd.DataFrame({'n_gram':sf.index, 'numberofcalls':sf.values})

# Define max and min threshold
min = 500
max = float("inf")
subset = freq[(freq['numberofcalls'] > min) & (freq['numberofcalls'] < max)]
subset
# Out:
#                                                 n_gram  numberofcalls
# 0    voidLAMMPS_NS::Run::command(int,char**):voidLA...         319405
# 1    voidLAMMPS_NS::Run::command(int,char**):voidLA...         319405
# 2    voidLAMMPS_NS::Run::command(int,char**):voidLA...         319405
# 3    voidLAMMPS_NS::Verlet::run(int):voidLAMMPS_NS:...         318649
# 4    voidLAMMPS_NS::Verlet::run(int):voidLAMMPS_NS:...         318649
# 5    voidLAMMPS_NS::Verlet::run(int):voidLAMMPS_NS:...         318649
# 6    voidLAMMPS_NS::Verlet::run(int):voidLAMMPS_NS:...         166320
# 7    voidLAMMPS_NS::Verlet::run(int):voidLAMMPS_NS:...         166320
# 8    voidLAMMPS_NS::Run::command(int,char**):voidLA...         166320
# 9    voidLAMMPS_NS::Verlet::run(int):voidLAMMPS_NS:...         166320
# 10   voidLAMMPS_NS::Verlet::run(int):voidLAMMPS_NS:...         166320
# 11   voidLAMMPS_NS::Run::command(int,char**):voidLA...         163548
# 12   voidLAMMPS_NS::Neighbor::build(int):voidLAMMPS...         112327
# 13   LAMMPS_NS::Input::command_creator:voidLAMMPS_N...          60816
# 14   voidLAMMPS_NS::Run::command(int,char**):voidLA...          22680
# 15   voidLAMMPS_NS::Modify::initial_integrate(int):...          15120
# 16   voidLAMMPS_NS::Modify::initial_integrate(int):...          15120
# 17   voidLAMMPS_NS::Verlet::run(int):voidLAMMPS_NS:...          15120
# 18   voidLAMMPS_NS::Modify::initial_integrate(int):...          15120
# 19   voidLAMMPS_NS::Modify::initial_integrate(int):...          15120
# 20   voidLAMMPS_NS::Verlet::run(int):voidLAMMPS_NS:...           7812
# 21   LAMMPS_NS::Input::command_creator:voidLAMMPS_N...           7602
# 22   LAMMPS_NS::Input::command_creator:voidLAMMPS_N...           7602
# 23   LAMMPS_NS::Input::command_creator:voidLAMMPS_N...           7602
# 24   LAMMPS_NS::Input::command_creator:voidLAMMPS_N...           7602
# 25   voidLAMMPS_NS::FixNH::initial_integrate(int):v...           7560
# 26   voidLAMMPS_NS::FixNH::final_integrate():voidLA...           7560
# 27   voidLAMMPS_NS::Run::command(int,char**):voidLA...           7560
# 28   voidLAMMPS_NS::Verlet::run(int):voidLAMMPS_NS:...           7560
# 29   LAMMPS_NS::Input::command_creator:voidLAMMPS_N...           7560
# ..                                                 ...            ...
# 77   voidLAMMPS_NS::Run::command(int,char**):voidLA...           2023
# 78   voidLAMMPS_NS::Run::command(int,char**):voidLA...           2023
# 79   LAMMPS_NS::Input::command_creator:voidLAMMPS_N...           2016
# 80   voidLAMMPS_NS::Verlet::setup():voidLAMMPS_NS::...           1771
# 81   voidLAMMPS_NS::Verlet::setup():voidLAMMPS_NS::...           1771
# 82   voidLAMMPS_NS::Verlet::setup():voidLAMMPS_NS::...           1771
# 83   voidLAMMPS_NS::Run::command(int,char**):voidLA...           1680
# 84     .TAUapplication:intmain(int,char**):MPI_Bcast()           1344
# 85   voidLAMMPS_NS::Run::command(int,char**):voidLA...           1176
# 86   voidLAMMPS_NS::Pair::init():voidLAMMPS_NS::Pai...            945
# 87   voidLAMMPS_NS::Run::command(int,char**):voidLA...            924
# 88   voidLAMMPS_NS::Run::command(int,char**):voidLA...            924
# 89   voidLAMMPS_NS::Verlet::setup():voidLAMMPS_NS::...            924
# 90   voidLAMMPS_NS::Run::command(int,char**):voidLA...            924
# 91   voidLAMMPS_NS::Verlet::setup():voidLAMMPS_NS::...            924
# 92   voidLAMMPS_NS::Verlet::setup():voidLAMMPS_NS::...            924
# 93   voidLAMMPS_NS::Verlet::setup():voidLAMMPS_NS::...            924
# 94   voidLAMMPS_NS::Verlet::run(int):voidLAMMPS_NS:...            846
# 95   voidLAMMPS_NS::Output::write(LAMMPS_NS::bigint...            846
# 96   voidLAMMPS_NS::Run::command(int,char**):voidLA...            756
# 97   voidLAMMPS_NS::LAMMPS::destroy():voidLAMMPS_NS...            735
# 98   LAMMPS_NS::Input::command_creator:voidLAMMPS_N...            694
# 99   LAMMPS_NS::Input::command_creator:voidLAMMPS_N...            692
# 100  LAMMPS_NS::Input::command_creator:voidLAMMPS_N...            692
# 101  .TAUapplication:intmain(int,char**):voidLAMMPS...            651
# 102  intmain(int,char**):voidLAMMPS_NS::Input::file...            651
# 103  LAMMPS_NS::Input::command_creator:voidLAMMPS_N...            651
# 104  voidLAMMPS_NS::Pair::init():voidLAMMPS_NS::Pai...            630
# 105  voidLAMMPS_NS::Pair::init():voidLAMMPS_NS::Pai...            630
# 106  LAMMPS_NS::Input::command_creator:voidLAMMPS_N...            588
#
# [107 rows x 2 columns]

# %%
sns.set_context("notebook", font_scale=1.2, rc={"lines.linewidth": 2.5})
for i in range(len(subset)):
    pick_func = freq.iloc[i]['n_gram']
    count  = freq.iloc[i]['numberofcalls']
    lbl = str(pick_func) +'_count_'+ str(count)
    df[df['kl'] == pick_func].plot(x='time_by_lasttime', y='time_diff', kind = 'scatter', title=lbl )
    plt.show()
