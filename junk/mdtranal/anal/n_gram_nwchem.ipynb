# %%
import pickle
# %matplotlib inline
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
with open('n_gram.df', 'rb') as handle:
    df = pd.read_pickle(handle)

# %%
df
# Out:
#                                                        kl  time_by_lasttime  \
# 0                         .TAUapplication:NWCHEM:F2C_IARG          0.001499
# 1                       .TAUapplication:NWCHEM:F2C_GETARG          0.001504
# 2                       .TAUapplication:NWCHEM:F2C_GETARG          0.001507
# 3       voidpbeginf_():voidtcgi_pbegin(int,char**):MPI...          0.001736
# 4       voidpbeginf_():voidtcgi_pbegin(int,char**):MPI...          0.013583
# 5       voidpbeginf_():voidtcgi_pbegin(int,char**):MPI...          0.013667
# 6       voidpbeginf_():voidtcgi_pbegin(int,char**):MPI...          0.013671
# 7       voidtcgi_alt_pbegin(int*,char***):voidinstall_...          0.013682
# 8       voidtcgi_pbegin(int,char**):voidtcgi_alt_pbegi...          0.013680
# 9       intPARMCI_Init_args(int*,char***):intcomex_ini...          0.014434
# 10      intPARMCI_Init_args(int*,char***):intcomex_ini...          0.014440
# 11      intPARMCI_Init_args(int*,char***):intcomex_ini...          0.014499
# 12      intcomex_init_args(int*,char***):intcomex_init...          0.022521
# 13      intPARMCI_Init_args(int*,char***):intcomex_ini...          0.022516
# 14      intcomex_init_args(int*,char***):intcomex_init...          0.022680
# 15      intcomex_init_args(int*,char***):intcomex_init...          0.022683
# 16      intcomex_init_args(int*,char***):intcomex_init...          0.022685
# 17      intcomex_init_args(int*,char***):intcomex_init...          0.022687
# 18      intcomex_init_args(int*,char***):intcomex_init...          0.022761
# 19      intcomex_init_args(int*,char***):intcomex_init...          0.022764
# 20      intcomex_init_args(int*,char***):intcomex_init...          0.022764
# 21      intcomex_init_args(int*,char***):intcomex_init...          0.022766
# 22      intcomex_init_args(int*,char***):intcomex_init...          0.022772
# 23      intcomex_init():intcomex_barrier(comex_group_t...          0.022859
# 24      intcomex_init():intcomex_barrier(comex_group_t...          0.022863
# 25      intcomex_init():intcomex_barrier(comex_group_t...          0.023021
# 26      intcomex_init_args(int*,char***):intcomex_init...          0.022854
# 27      intcomex_init():intcomex_barrier(comex_group_t...          0.023023
# 28      intcomex_init():intcomex_barrier(comex_group_t...          0.023023
# 29      intcomex_init():intcomex_barrier(comex_group_t...          0.023024
# ...                                                   ...               ...
# 116051  intcomex_finalize():intcomex_barrier(comex_gro...          0.999606
# 116052  voidPARMCI_Finalize():intcomex_finalize():void...          0.999602
# 116053  intcomex_finalize():intcomex_barrier(comex_gro...          0.999607
# 116054  intcomex_finalize():intcomex_barrier(comex_gro...          0.999607
# 116055  intcomex_finalize():intcomex_barrier(comex_gro...          0.999607
# 116056  voidPARMCI_Finalize():intcomex_finalize():void...          0.999607
# 116057  intcomex_finalize():intcomex_barrier(comex_gro...          0.999607
# 116058  intcomex_finalize():intcomex_barrier(comex_gro...          0.999607
# 116059  intcomex_finalize():intcomex_barrier(comex_gro...          0.999607
# 116060  voidPARMCI_Finalize():intcomex_finalize():void...          0.999607
# 116061  voidPARMCI_Finalize():intcomex_finalize():void...          0.999607
# 116062  voidPARMCI_Finalize():intcomex_finalize():void...          0.999609
# 116063  voidPARMCI_Finalize():intcomex_finalize():void...          0.999609
# 116064  voidARMCI_Finalize():voidPARMCI_Finalize():int...          0.999591
# 116065  voidPARMCI_Finalize():intcomex_finalize():MPI_...          0.999712
# 116066  voidARMCI_Finalize():voidPARMCI_Finalize():add...          0.999711
# 116067  voidARMCI_Finalize():voidPARMCI_Finalize():MPI...          0.999716
# 116068  voidpnga_terminate():voidARMCI_Finalize():intc...          0.999589
# 116069  voidga_terminate_():voidpnga_terminate():voidP...          0.999587
# 116070    NWCHEM:voidga_terminate_():voidARMCI_Finalize()          0.999583
# 116071        .TAUapplication:NWCHEM:voidpnga_terminate()          0.999383
# 116072                .TAUapplication:voidga_terminate_()          0.999379
# 116073  voidfinalize_nxtval():voidARMCI_Finalize():int...          0.999729
# 116074  voidarmci_tcgmsg_pend():voidfinalize_nxtval():...          0.999727
# 116075  voidpend_():voidarmci_tcgmsg_pend():voidARMCI_...          0.999725
# 116076           NWCHEM:voidpend_():voidfinalize_nxtval()          0.999725
# 116077                  NWCHEM:voidpend_():MPI_Finalize()          0.999731
# 116078     .TAUapplication:NWCHEM:voidarmci_tcgmsg_pend()          0.999722
# 116079                        .TAUapplication:voidpend_()          0.999720
# 116080                                             NWCHEM          0.000405
#
#          time_diff node_id thread_id
# 0            177.0       0         0
# 1            134.0       0         0
# 2             13.0       0         0
# 3         624081.0       0         0
# 4            266.0       0         0
# 5            133.0       0         0
# 6            118.0       0         0
# 7            118.0       0         0
# 8            235.0       0         0
# 9            298.0       0         0
# 10           127.0       0         0
# 11           139.0       0         0
# 12           150.0       0         0
# 13           420.0       0         0
# 14           130.0       0         0
# 15           130.0       0         0
# 16           120.0       0         0
# 17           110.0       0         0
# 18           140.0       0         0
# 19             0.0       0         0
# 20             0.0       0         0
# 21           230.0       0         0
# 22           200.0       0         0
# 23           120.0       0         0
# 24           300.0       0         0
# 25           140.0       0         0
# 26          9180.0       0         0
# 27             0.0       0         0
# 28            10.0       0         0
# 29             0.0       0         0
# ...            ...     ...       ...
# 116051       100.0       0         0
# 116052       300.0       0         0
# 116053         0.0       0         0
# 116054         0.0       0         0
# 116055         0.0       0         0
# 116056         0.0       0         0
# 116057         0.0       0         0
# 116058         0.0       0         0
# 116059         0.0       0         0
# 116060         0.0       0         0
# 116061       100.0       0         0
# 116062         0.0       0         0
# 116063         0.0       0         0
# 116064      1000.0       0         0
# 116065       100.0       0         0
# 116066       200.0       0         0
# 116067       100.0       0         0
# 116068      7000.0       0         0
# 116069      7100.0       0         0
# 116070      7300.0       0         0
# 116071     18200.0       0         0
# 116072     18400.0       0         0
# 116073       100.0       0         0
# 116074       200.0       0         0
# 116075       300.0       0         0
# 116076       300.0       0         0
# 116077     14600.0       0         0
# 116078     15100.0       0         0
# 116079     15200.0       0         0
# 116080  54229727.0       0         0
#
# [116081 rows x 5 columns]

# %%
df = df.sort(['time_by_lasttime'], ascending=[True])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-680d34bee415> in <module>()
# ----> 1 df = df.sort(['time_by_lasttime'], ascending=[True])
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'sort'

# %%
import pandas as pd
sf = df.kl.value_counts()
freq = pd.DataFrame({'n_gram':sf.index, 'numberofcalls':sf.values})

# Define max and min threshold
min = 500
max = float("inf")
subset = freq[(freq['numberofcalls'] > min) & (freq['numberofcalls'] < max)]
subset
# Out:
#                                                n_gram  numberofcalls
# 0   inthdbm_close(hdbm):inthdbm_clear(hdbm):voidda...           6570
# 1                          ANALYZ:ANA_TASK:UTIL_PRINT           4400
# 2   inthdbm_close(hdbm):inthdbm_clear(hdbm):inthdb...           4385
# 3   inthdbm_close(hdbm):inthdbm_clear(hdbm):voidhd...           4380
# 4   inthdbm_file_compress(constchar*):inthdbm_file...           2634
# 5   inthdbm_insert(hdbm,datum,datum):entry*NewEntr...           2628
# 6   inthdbm_file_copy(constchar*,constchar*):inthd...           2628
# 7                              TASK:ANALYZ:ANA_RDFRAM           2200
# 8                              TASK:ANALYZ:ANA_WTFRAM           2200
# 9   inthdbm_clear(hdbm):inthdbm_delete(hdbm,datum)...           2190
# 10  inthdbm_close(hdbm):inthdbm_clear(hdbm):voidse...           2190
# 11  inthdbm_clear(hdbm):inthdbm_delete(hdbm,datum)...           2190
# 12  inthdbm_close(hdbm):inthdbm_clear(hdbm):intdat...           2190
# 13  inthdbm_clear(hdbm):inthdbm_next_key(hdbm,datu...           2185
# 14  inthdbm_file_compress(constchar*):inthdbm_file...           1764
# 15  inthdbm_open(constchar*,int,hdbm*):inthdbm_loa...           1752
# 16  inthdbm_file_copy(constchar*,constchar*):inthd...           1752
# 17  intrtdb_seq_close(constint,constchar*):inthdbm...           1752
# 18  inthdbm_open(constchar*,int,hdbm*):inthdbm_loa...           1752
# 19  inthdbm_file_copy(constchar*,constchar*):inthd...           1752
# 20  inthdbm_file_copy(constchar*,constchar*):inthd...           1752
# 21  inthdbm_file_copy(constchar*,constchar*):inthd...           1752
# 22  inthdbm_file_copy(constchar*,constchar*):inthd...           1752
# 23  inthdbm_replace(hdbm,datum,datum):inthdbm_inse...           1314
# 24                    INPUT_PARSE:MD_INPUT:INP_STRLEN            970
# 25  inthdbm_file_copy(constchar*,constchar*):inthd...            880
# 26  inthdbm_file_copy(constchar*,constchar*):inthd...            880
# 27  inthdbm_file_copy(constchar*,constchar*):inthd...            876
# 28  inthdbm_load(hdbm,FILE*):entry*NewEntry(datum,...            876
# 29  inthdbm_file_copy(constchar*,constchar*):inthd...            876
# 30  inthdbm_file_compress(constchar*):inthdbm_file...            876
# 31  inthdbm_file_compress(constchar*):inthdbm_file...            876
# 32  inthdbm_open(constchar*,int,hdbm*):inthdbm_loa...            876
# 33  intrtdb_seq_close(constint,constchar*):inthdbm...            876
# 34  inthdbm_open(constchar*,int,hdbm*):inthdbm_loa...            876
# 35  inthdbm_file_compress(constchar*):inthdbm_file...            876
# 36  intrtdb_seq_close(constint,constchar*):inthdbm...            876
# 37  inthdbm_open(constchar*,int,hdbm*):inthdbm_loa...            876
# 38  inthdbm_file_compress(constchar*):inthdbm_file...            876
# 39  inthdbm_file_copy(constchar*,constchar*):inthd...            876
# 40  inthdbm_replace(hdbm,datum,datum):inthdbm_inse...            876
# 41  inthdbm_open(constchar*,int,hdbm*):inthdbm_loa...            876
# 42  inthdbm_file_copy(constchar*,constchar*):inthd...            876
# 43  inthdbm_file_copy(constchar*,constchar*):inthd...            876
# 44  inthdbm_file_compress(constchar*):inthdbm_file...            876
# 45  inthdbm_file_copy(constchar*,constchar*):inthd...            876
# 46  intrtdb_seq_close(constint,constchar*):inthdbm...            876
# 47  inthdbm_file_compress(constchar*):inthdbm_file...            876
# 48  inthdbm_file_copy(constchar*,constchar*):inthd...            876
# 49  inthdbm_file_copy(constchar*,constchar*):inthd...            876
# 50  inthdbm_file_compress(constchar*):inthdbm_file...            876
# 51  inthdbm_file_copy(constchar*,constchar*):inthd...            876
# 52  inthdbm_file_copy(constchar*,constchar*):inthd...            876
# 53  inthdbm_file_copy(constchar*,constchar*):inthd...            876
# 54  inthdbm_file_copy(constchar*,constchar*):inthd...            874
# 55                      NWCHEM:INPUT_PARSE:INP_STRLEN            849
# 56                     NWCHEM:INPUT_PARSE:INP_COMPARE            712

# %%
sns.set_context("notebook", font_scale=1.2, rc={"lines.linewidth": 2.5})
for i in range(len(subset)):
    pick_func = freq.iloc[i]['n_gram']
    count  = freq.iloc[i]['numberofcalls']
    lbl = str(pick_func) +'_count_'+ str(count)
    df[df['kl'] == pick_func].plot(x='time_by_lasttime', y='time_diff', kind = 'scatter', title=lbl )
    plt.show()
